# %%
import pandas as pd
import numpy as np
import psycopg2

# %%
user_data = pd.read_sql(
    """SELECT * FROM public.user_data""",
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

# %%
post_data = pd.read_sql(
    """SELECT * FROM public.post_text_df""",
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

# %%
feed_action_data = pd.read_sql(
    """SELECT * FROM public.feed_data LIMIT 12000000""",
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

# %%
user_data.head()
# Out:
#    user_id  gender  age country               city  exp_group       os source
# 0      200       1   34  Russia          Degtyarsk          3  Android    ads
# 1      201       0   37  Russia             Abakan          0  Android    ads
# 2      202       1   17  Russia           Smolensk          4  Android    ads
# 3      203       0   18  Russia             Moscow          1      iOS    ads
# 4      204       0   36  Russia  Anzhero-Sudzhensk          3  Android    ads

# %%
post_data.head()
# Out:
#    post_id                                               text     topic
# 0        1  UK economy facing major risks\n\nThe UK manufa...  business
# 1        2  Aids and climate top Davos agenda\n\nClimate c...  business
# 2        3  Asian quake hits European shares\n\nShares in ...  business
# 3        4  India power shares jump on debut\n\nShares in ...  business
# 4        5  Lacroix label bought by US firm\n\nLuxury good...  business

# %%
feed_action_data.head()
# Out:
#             timestamp  user_id  post_id action  target
# 0 2021-11-25 12:42:00    51735     1418   view       0
# 1 2021-11-25 12:44:40    51735     3667   view       0
# 2 2021-11-25 12:47:38    51735     7075   view       0
# 3 2021-11-25 12:49:29    51735     4478   view       0
# 4 2021-11-25 12:51:45    51735     6784   view       0

# %%
feed_action_data[feed_action_data.action != 'like']
# Out:
#                   timestamp  user_id  post_id action  target
# 0       2021-11-25 12:42:00    51735     1418   view       0
# 1       2021-11-25 12:44:40    51735     3667   view       0
# 2       2021-11-25 12:47:38    51735     7075   view       0
# 3       2021-11-25 12:49:29    51735     4478   view       0
# 4       2021-11-25 12:51:45    51735     6784   view       0
# ...                     ...      ...      ...    ...     ...
# 9999994 2021-12-29 07:33:17   162399     3402   view       0
# 9999995 2021-12-29 07:35:14   162399     6747   view       1
# 9999997 2021-12-29 07:38:11   162399     2274   view       0
# 9999998 2021-12-29 07:38:26   162399     1909   view       0
# 9999999 2021-12-29 07:40:58   162399     1401   view       0
#
# [8931952 rows x 5 columns]

# %%
feed_data = feed_action_data[feed_action_data.action != 'like']
feed_data.shape
# Out:
# (8931952, 5)

# %%
df = feed_data.merge(post_data, how='left', on='post_id').merge(user_data, how='left', on='user_id')
df
# Out:
#                   timestamp  user_id  post_id action  target  \
# 0       2021-11-25 12:42:00    51735     1418   view       0
# 1       2021-11-25 12:44:40    51735     3667   view       0
# 2       2021-11-25 12:47:38    51735     7075   view       0
# 3       2021-11-25 12:49:29    51735     4478   view       0
# 4       2021-11-25 12:51:45    51735     6784   view       0
# ...                     ...      ...      ...    ...     ...
# 8931947 2021-12-29 07:33:17   162399     3402   view       0
# 8931948 2021-12-29 07:35:14   162399     6747   view       1
# 8931949 2021-12-29 07:38:11   162399     2274   view       0
# 8931950 2021-12-29 07:38:26   162399     1909   view       0
# 8931951 2021-12-29 07:40:58   162399     1401   view       0
#
#                                                       text  topic  gender  \
# 0        Yelling takes Cardiff hat-trick\n\nEuropean cr...  sport       1
# 1        Time’s up! Thx for using #SaludTues to promote...  covid       1
# 2        This film is the worst film, but it ranks very...  movie       1
# 3        I really enjoyed this movie. The humor was a b...  movie       1
# 4        As a former Kalamazoo resident with a fondness...  movie       1
# ...                                                    ...    ...     ...
# 8931947  @Mangold_Lenett This needs to be hashtag #real...  covid       0
# 8931948  I grew up in Baltimore, so I was exposed to th...  movie       0
# 8931949  Microsoft debuts security tools\n\nMicrosoft i...   tech       0
# 8931950  Trial date is set for Balco case\n\nA US judge...  sport       0
# 8931951  Munster Cup tie switched to Spain\n\nMunsters ...  sport       0
#
#          age country        city  exp_group       os   source
# 0         27  Russia      Moscow          3      iOS      ads
# 1         27  Russia      Moscow          3      iOS      ads
# 2         27  Russia      Moscow          3      iOS      ads
# 3         27  Russia      Moscow          3      iOS      ads
# 4         27  Russia      Moscow          3      iOS      ads
# ...      ...     ...         ...        ...      ...      ...
# 8931947   48  Russia  Kurovskoye          0  Android  organic
# 8931948   48  Russia  Kurovskoye          0  Android  organic
# 8931949   48  Russia  Kurovskoye          0  Android  organic
# 8931950   48  Russia  Kurovskoye          0  Android  organic
# 8931951   48  Russia  Kurovskoye          0  Android  organic
#
# [8931952 rows x 14 columns]

# %%
df['hour'] = pd.to_datetime(df['timestamp']).apply(lambda x: x.hour)
df['month'] = pd.to_datetime(df['timestamp']).apply(lambda x: x.month)
# df['weekday'] = pd.to_datetime(df['timestamp']).apply(lambda x: x.dayofweek)
df.head()
# Out:
#             timestamp  user_id  post_id action  target  \
# 0 2021-11-25 12:42:00    51735     1418   view       0
# 1 2021-11-25 12:44:40    51735     3667   view       0
# 2 2021-11-25 12:47:38    51735     7075   view       0
# 3 2021-11-25 12:49:29    51735     4478   view       0
# 4 2021-11-25 12:51:45    51735     6784   view       0
#
#                                                 text  topic  gender  age  \
# 0  Yelling takes Cardiff hat-trick\n\nEuropean cr...  sport       1   27
# 1  Time’s up! Thx for using #SaludTues to promote...  covid       1   27
# 2  This film is the worst film, but it ranks very...  movie       1   27
# 3  I really enjoyed this movie. The humor was a b...  movie       1   27
# 4  As a former Kalamazoo resident with a fondness...  movie       1   27
#
#   country    city  exp_group   os source  hour  month
# 0  Russia  Moscow          3  iOS    ads    12     11
# 1  Russia  Moscow          3  iOS    ads    12     11
# 2  Russia  Moscow          3  iOS    ads    12     11
# 3  Russia  Moscow          3  iOS    ads    12     11
# 4  Russia  Moscow          3  iOS    ads    12     11

# %%
df = df.drop(['action', 'text'], axis=1)

df = df.set_index(['user_id', 'post_id'])

df.head(50)
# Out:
#                           timestamp  target          topic  gender  age  \
# user_id post_id
# 51735   1418    2021-11-25 12:42:00       0          sport       1   27
#         3667    2021-11-25 12:44:40       0          covid       1   27
#         7075    2021-11-25 12:47:38       0          movie       1   27
#         4478    2021-11-25 12:49:29       0          movie       1   27
#         6784    2021-11-25 12:51:45       0          movie       1   27
#         6541    2021-11-25 12:52:30       0          movie       1   27
#         1820    2021-11-28 20:31:05       0          sport       1   27
#         189     2021-11-28 20:33:36       0       business       1   27
#         1742    2021-11-28 20:36:34       0          sport       1   27
#         2999    2021-11-28 20:36:54       0          covid       1   27
#         4120    2021-11-28 20:37:30       0          covid       1   27
#         1568    2021-11-28 20:39:22       0          sport       1   27
#         4252    2021-11-28 20:40:40       1          movie       1   27
#         5231    2021-11-28 20:43:05       0          movie       1   27
#         620     2021-11-28 20:44:07       0  entertainment       1   27
#         5201    2021-11-28 20:46:17       0          movie       1   27
#         835     2021-11-28 20:47:14       0  entertainment       1   27
#         2994    2021-11-28 20:49:49       0          covid       1   27
#         981     2021-11-28 20:51:50       0       politics       1   27
#         3006    2021-11-28 20:53:36       0          covid       1   27
#         3171    2021-11-28 20:56:01       0          covid       1   27
#         6168    2021-11-28 20:56:51       0          movie       1   27
#         6730    2021-11-28 20:57:15       0          movie       1   27
#         6138    2021-11-28 20:58:36       0          movie       1   27
#         4070    2021-11-28 21:00:07       0          covid       1   27
#         2322    2021-11-28 21:01:26       0           tech       1   27
#         6123    2021-11-28 21:03:37       0          movie       1   27
#         6349    2021-11-28 21:06:32       0          movie       1   27
#         946     2021-11-28 21:08:03       0       politics       1   27
#         2910    2021-11-28 21:11:01       0          covid       1   27
#         5206    2021-11-28 21:13:07       0          movie       1   27
#         5797    2021-11-28 21:13:50       0          movie       1   27
#         4816    2021-11-28 21:15:34       0          movie       1   27
#         2810    2021-11-30 14:00:53       0          covid       1   27
#         5560    2021-11-30 14:03:40       1          movie       1   27
#         1765    2021-11-30 14:04:30       0          sport       1   27
#         1304    2021-11-30 14:04:54       0       politics       1   27
#         543     2021-11-30 14:05:36       0  entertainment       1   27
#         3801    2021-11-30 14:07:24       0          covid       1   27
#         1687    2021-11-30 14:08:48       0          sport       1   27
#         253     2021-11-30 14:11:00       0       business       1   27
#         5398    2021-11-30 14:13:43       0          movie       1   27
# 86499   1001    2021-12-24 09:56:58       1       politics       1   25
#         473     2021-12-24 09:59:21       1       business       1   25
#         718     2021-12-24 09:59:38       0  entertainment       1   25
#         936     2021-12-24 10:01:41       0  entertainment       1   25
#         3712    2021-12-24 10:04:17       0          covid       1   25
#         5068    2021-12-24 10:06:37       0          movie       1   25
#         3400    2021-12-24 10:08:05       0          covid       1   25
#         1682    2021-12-24 10:10:02       0          sport       1   25
#
#                 country              city  exp_group   os source  hour  month
# user_id post_id
# 51735   1418     Russia            Moscow          3  iOS    ads    12     11
#         3667     Russia            Moscow          3  iOS    ads    12     11
#         7075     Russia            Moscow          3  iOS    ads    12     11
#         4478     Russia            Moscow          3  iOS    ads    12     11
#         6784     Russia            Moscow          3  iOS    ads    12     11
#         6541     Russia            Moscow          3  iOS    ads    12     11
#         1820     Russia            Moscow          3  iOS    ads    20     11
#         189      Russia            Moscow          3  iOS    ads    20     11
#         1742     Russia            Moscow          3  iOS    ads    20     11
#         2999     Russia            Moscow          3  iOS    ads    20     11
#         4120     Russia            Moscow          3  iOS    ads    20     11
#         1568     Russia            Moscow          3  iOS    ads    20     11
#         4252     Russia            Moscow          3  iOS    ads    20     11
#         5231     Russia            Moscow          3  iOS    ads    20     11
#         620      Russia            Moscow          3  iOS    ads    20     11
#         5201     Russia            Moscow          3  iOS    ads    20     11
#         835      Russia            Moscow          3  iOS    ads    20     11
#         2994     Russia            Moscow          3  iOS    ads    20     11
#         981      Russia            Moscow          3  iOS    ads    20     11
#         3006     Russia            Moscow          3  iOS    ads    20     11
#         3171     Russia            Moscow          3  iOS    ads    20     11
#         6168     Russia            Moscow          3  iOS    ads    20     11
#         6730     Russia            Moscow          3  iOS    ads    20     11
#         6138     Russia            Moscow          3  iOS    ads    20     11
#         4070     Russia            Moscow          3  iOS    ads    21     11
#         2322     Russia            Moscow          3  iOS    ads    21     11
#         6123     Russia            Moscow          3  iOS    ads    21     11
#         6349     Russia            Moscow          3  iOS    ads    21     11
#         946      Russia            Moscow          3  iOS    ads    21     11
#         2910     Russia            Moscow          3  iOS    ads    21     11
#         5206     Russia            Moscow          3  iOS    ads    21     11
#         5797     Russia            Moscow          3  iOS    ads    21     11
#         4816     Russia            Moscow          3  iOS    ads    21     11
#         2810     Russia            Moscow          3  iOS    ads    14     11
#         5560     Russia            Moscow          3  iOS    ads    14     11
#         1765     Russia            Moscow          3  iOS    ads    14     11
#         1304     Russia            Moscow          3  iOS    ads    14     11
#         543      Russia            Moscow          3  iOS    ads    14     11
#         3801     Russia            Moscow          3  iOS    ads    14     11
#         1687     Russia            Moscow          3  iOS    ads    14     11
#         253      Russia            Moscow          3  iOS    ads    14     11
#         5398     Russia            Moscow          3  iOS    ads    14     11
# 86499   1001     Russia  Velikiy Novgorod          3  iOS    ads     9     12
#         473      Russia  Velikiy Novgorod          3  iOS    ads     9     12
#         718      Russia  Velikiy Novgorod          3  iOS    ads     9     12
#         936      Russia  Velikiy Novgorod          3  iOS    ads    10     12
#         3712     Russia  Velikiy Novgorod          3  iOS    ads    10     12
#         5068     Russia  Velikiy Novgorod          3  iOS    ads    10     12
#         3400     Russia  Velikiy Novgorod          3  iOS    ads    10     12
#         1682     Russia  Velikiy Novgorod          3  iOS    ads    10     12

# %%
max(df.timestamp), min(df.timestamp)
# Out:
# (Timestamp('2021-12-29 23:43:15'), Timestamp('2021-10-01 06:01:40'))

# %%
df_train = df[df.timestamp < '2021-12-8']
df_test = df[df.timestamp >= '2021-12-8']

df_train = df_train.drop('timestamp', axis=1)
df_test = df_test.drop('timestamp', axis=1)

X_train = df_train.drop('target', axis=1)
X_test = df_test.drop('target', axis=1)

y_train = df_train['target']
y_test = df_test['target']

y_train.shape, y_test.shape
# Out:
# ((6792144,), (2139808,))

# %%
df.columns
# Out:
# Index(['timestamp', 'target', 'topic', 'gender', 'age', 'country', 'city',
#        'exp_group', 'os', 'source', 'hour', 'month'],
#       dtype='object')

# %%
from sklearn.compose import ColumnTransformer
from category_encoders import TargetEncoder
from category_encoders.one_hot import OneHotEncoder

object_cols = ['topic', 'gender', 'age', 'country', 'city',
       'exp_group', 'os', 'source', 'hour', 'month']

cols_for_ohe = [x for x in object_cols if X_train[x].nunique() < 5]
cols_for_mte = [x for x in object_cols if X_train[x].nunique() >= 5]


cols_for_ohe_idx = [list(X_train.columns).index(col) for col in cols_for_ohe]
cols_for_mte_idx = [list(X_train.columns).index(col) for col in cols_for_mte]

t = [
    ('OneHotEncoder', OneHotEncoder(), cols_for_ohe_idx),
    ('MeanTargetEncoder', TargetEncoder(), cols_for_mte_idx)
]

col_transform = ColumnTransformer(transformers=t)

from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline

pipe_dt = Pipeline([("column_transformer",
                     col_transform),
                     
                    ("decision_tree", 
                     DecisionTreeClassifier())])

pipe_dt.fit(X_train, y_train)
# Out:
# C:\Users\argym\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\externals\_numpydoc\docscrape.py:420: UserWarning: Unknown section Example
#   self[section] = content
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(transformers=[('OneHotEncoder',
#                                                   OneHotEncoder(),
#                                                   [1, 6, 7, 9]),
#                                                  ('MeanTargetEncoder',
#                                                   TargetEncoder(),
#                                                   [0, 2, 3, 4, 5, 8])])),
#                 ('decision_tree', DecisionTreeClassifier())])

# %%
from sklearn.metrics import roc_auc_score

print(f"Качество на трейне: {roc_auc_score(y_train, pipe_dt.predict_proba(X_train)[:, 1])}")
print(f"Качество на тесте: {roc_auc_score(y_test, pipe_dt.predict_proba(X_test)[:, 1])}")
# Out:
# Качество на трейне: 0.8807697975025448
# Качество на тесте: 0.5422454201976419

# %%
from catboost import CatBoostClassifier

catboost = CatBoostClassifier(iterations=100,
                              learning_rate=1,
                              depth=2)

catboost.fit(X_train, y_train, object_cols)
# Out:
# 0:	learn: 0.3674798	total: 1.22s	remaining: 2m 1s
# 1:	learn: 0.3503802	total: 2.22s	remaining: 1m 48s
# 2:	learn: 0.3444000	total: 2.98s	remaining: 1m 36s
# 3:	learn: 0.3431757	total: 3.66s	remaining: 1m 27s
# 4:	learn: 0.3427106	total: 4.35s	remaining: 1m 22s
# 5:	learn: 0.3424009	total: 4.91s	remaining: 1m 16s
# 6:	learn: 0.3422472	total: 5.48s	remaining: 1m 12s
# 7:	learn: 0.3421433	total: 5.99s	remaining: 1m 8s
# 8:	learn: 0.3420985	total: 6.51s	remaining: 1m 5s
# 9:	learn: 0.3418103	total: 7.13s	remaining: 1m 4s
# 10:	learn: 0.3417884	total: 7.62s	remaining: 1m 1s
# 11:	learn: 0.3417622	total: 8.13s	remaining: 59.6s
# 12:	learn: 0.3417490	total: 8.67s	remaining: 58.1s
# 13:	learn: 0.3417436	total: 9.18s	remaining: 56.4s
# 14:	learn: 0.3417081	total: 9.68s	remaining: 54.9s
# 15:	learn: 0.3417068	total: 10.2s	remaining: 53.7s
# 16:	learn: 0.3417063	total: 10.8s	remaining: 52.5s
# 17:	learn: 0.3405047	total: 11.3s	remaining: 51.4s
# 18:	learn: 0.3400722	total: 11.8s	remaining: 50.2s
# 19:	learn: 0.3399654	total: 12.2s	remaining: 49s
# 20:	learn: 0.3398171	total: 12.7s	remaining: 47.8s
# 21:	learn: 0.3395729	total: 13.2s	remaining: 46.8s
# 22:	learn: 0.3394843	total: 13.8s	remaining: 46.1s
# 23:	learn: 0.3391890	total: 14.3s	remaining: 45.3s
# 24:	learn: 0.3390608	total: 14.9s	remaining: 44.6s
# 25:	learn: 0.3389993	total: 15.4s	remaining: 43.8s
# 26:	learn: 0.3388626	total: 15.9s	remaining: 43.1s
# 27:	learn: 0.3388438	total: 16.5s	remaining: 42.4s
# 28:	learn: 0.3388385	total: 17s	remaining: 41.6s
# 29:	learn: 0.3388003	total: 17.5s	remaining: 40.9s
# 30:	learn: 0.3387790	total: 18.1s	remaining: 40.2s
# 31:	learn: 0.3387552	total: 18.5s	remaining: 39.4s
# 32:	learn: 0.3387533	total: 19.1s	remaining: 38.7s
# 33:	learn: 0.3387518	total: 19.5s	remaining: 37.9s
# 34:	learn: 0.3387507	total: 20s	remaining: 37.2s
# 35:	learn: 0.3387371	total: 20.5s	remaining: 36.4s
# 36:	learn: 0.3387363	total: 21s	remaining: 35.8s
# 37:	learn: 0.3387355	total: 21.5s	remaining: 35.1s
# 38:	learn: 0.3387354	total: 22s	remaining: 34.4s
# 39:	learn: 0.3387354	total: 22.5s	remaining: 33.8s
# 40:	learn: 0.3387354	total: 23s	remaining: 33.1s
# 41:	learn: 0.3387334	total: 23.6s	remaining: 32.6s
# 42:	learn: 0.3387327	total: 24.1s	remaining: 32s
# 43:	learn: 0.3387323	total: 24.6s	remaining: 31.4s
# 44:	learn: 0.3387323	total: 25.2s	remaining: 30.8s
# 45:	learn: 0.3387323	total: 25.8s	remaining: 30.2s
# 46:	learn: 0.3387276	total: 26.3s	remaining: 29.6s
# 47:	learn: 0.3387274	total: 26.8s	remaining: 29.1s
# 48:	learn: 0.3387272	total: 27.4s	remaining: 28.5s
# 49:	learn: 0.3387268	total: 28s	remaining: 28s
# 50:	learn: 0.3387225	total: 28.5s	remaining: 27.4s
# 51:	learn: 0.3386611	total: 29s	remaining: 26.8s
# 52:	learn: 0.3386174	total: 29.5s	remaining: 26.1s
# 53:	learn: 0.3385870	total: 30s	remaining: 25.5s
# 54:	learn: 0.3385661	total: 30.4s	remaining: 24.9s
# 55:	learn: 0.3385407	total: 30.9s	remaining: 24.3s
# 56:	learn: 0.3385291	total: 31.4s	remaining: 23.7s
# 57:	learn: 0.3385281	total: 31.8s	remaining: 23.1s
# 58:	learn: 0.3385281	total: 32.3s	remaining: 22.5s
# 59:	learn: 0.3385281	total: 32.9s	remaining: 21.9s
# 60:	learn: 0.3385262	total: 33.4s	remaining: 21.4s
# 61:	learn: 0.3385260	total: 33.9s	remaining: 20.8s
# 62:	learn: 0.3385258	total: 34.4s	remaining: 20.2s
# 63:	learn: 0.3385247	total: 34.9s	remaining: 19.6s
# 64:	learn: 0.3385051	total: 35.4s	remaining: 19.1s
# 65:	learn: 0.3385040	total: 36s	remaining: 18.5s
# 66:	learn: 0.3385038	total: 36.5s	remaining: 18s
# 67:	learn: 0.3385038	total: 37s	remaining: 17.4s
# 68:	learn: 0.3385027	total: 37.5s	remaining: 16.9s
# 69:	learn: 0.3385027	total: 38.1s	remaining: 16.3s
# 70:	learn: 0.3385026	total: 38.6s	remaining: 15.8s
# 71:	learn: 0.3385026	total: 39.1s	remaining: 15.2s
# 72:	learn: 0.3385026	total: 39.7s	remaining: 14.7s
# 73:	learn: 0.3384943	total: 40.2s	remaining: 14.1s
# 74:	learn: 0.3384918	total: 40.6s	remaining: 13.5s
# 75:	learn: 0.3384918	total: 41.2s	remaining: 13s
# 76:	learn: 0.3384871	total: 41.8s	remaining: 12.5s
# 77:	learn: 0.3384806	total: 42.3s	remaining: 11.9s
# 78:	learn: 0.3384799	total: 42.9s	remaining: 11.4s
# 79:	learn: 0.3384616	total: 43.4s	remaining: 10.9s
# 80:	learn: 0.3384527	total: 44s	remaining: 10.3s
# 81:	learn: 0.3384503	total: 44.5s	remaining: 9.78s
# 82:	learn: 0.3384503	total: 45.1s	remaining: 9.24s
# 83:	learn: 0.3384499	total: 45.7s	remaining: 8.7s
# 84:	learn: 0.3384491	total: 46.2s	remaining: 8.16s
# 85:	learn: 0.3384215	total: 46.8s	remaining: 7.62s
# 86:	learn: 0.3384215	total: 47.4s	remaining: 7.08s
# 87:	learn: 0.3384197	total: 47.9s	remaining: 6.54s
# 88:	learn: 0.3384196	total: 48.5s	remaining: 5.99s
# 89:	learn: 0.3384196	total: 49.1s	remaining: 5.45s
# 90:	learn: 0.3384196	total: 49.6s	remaining: 4.91s
# 91:	learn: 0.3384196	total: 50.2s	remaining: 4.36s
# 92:	learn: 0.3384196	total: 50.7s	remaining: 3.82s
# 93:	learn: 0.3384091	total: 51.2s	remaining: 3.27s
# 94:	learn: 0.3384091	total: 51.8s	remaining: 2.73s
# 95:	learn: 0.3384091	total: 52.4s	remaining: 2.18s
# 96:	learn: 0.3384091	total: 52.9s	remaining: 1.64s
# 97:	learn: 0.3384090	total: 53.5s	remaining: 1.09s
# 98:	learn: 0.3384090	total: 54s	remaining: 546ms
# 99:	learn: 0.3384089	total: 54.6s	remaining: 0us

# %%
print(f"Качество на трейне: {roc_auc_score(y_train, catboost.predict_proba(X_train)[:, 1])}")
print(f"Качество на тесте: {roc_auc_score(y_test, catboost.predict_proba(X_test)[:, 1])}")
# Out:
# Качество на трейне: 0.6584497407211056
# Качество на тесте: 0.6398471369714092

# %%
catboost.save_model(
    'catboost_model',
    format="cbm"                  
)

# %%
from_file = CatBoostClassifier()  # здесь не указываем параметры, которые были при обучении, в дампе модели все есть

from_file.load_model("catboost_model")

from_file.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Cell In[29], line 3
#       1 from_file = CatBoostClassifier()  # здесь не указываем параметры, которые были при обучении, в дампе модели все есть
# ----> 3 from_file.load_model("catboost_model")
#       5 from_file.predict(X_train)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\catboost\core.py:3452, in CatBoost.load_model(self, fname, format, stream, blob)
#    3449     raise CatBoostError("Exactly one of fname/stream/blob arguments mustn't be None")
#    3451 if fname is not None:
# -> 3452     self._load_model(fname, format)
#    3453 elif stream is not None:
#    3454     self._load_from_stream(stream)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\catboost\core.py:1913, in _CatBoostBase._load_model(self, model_file, format)
#    1911     raise CatBoostError("Invalid fname type={}: must be str() or pathlib.Path().".format(type(model_file)))
#    1912 self._init_params = {}
# -> 1913 self._object._load_model(model_file, format)
#    1914 self._set_trained_model_attributes()
#    1915 for key, value in iteritems(self._get_params()):
#
# File _catboost.pyx:5386, in _catboost._CatBoost._load_model()
#
# File _catboost.pyx:5389, in _catboost._CatBoost._load_model()
#
# CatBoostError: catboost/libs/model/model_import_interface.h:19: Model file doesn't exist: catboost_model

# %%
from_file.predict_proba(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from_file.predict_proba(X_train)
#
# NameError: name 'from_file' is not defined

# %%
df_new = df.reset_index().drop(columns=['timestamp', 'target'], axis=1)
df_new
# Out:
#          user_id  post_id  topic  gender  age country        city  exp_group  \
# 0          51735     1418  sport       1   27  Russia      Moscow          3
# 1          51735     3667  covid       1   27  Russia      Moscow          3
# 2          51735     7075  movie       1   27  Russia      Moscow          3
# 3          51735     4478  movie       1   27  Russia      Moscow          3
# 4          51735     6784  movie       1   27  Russia      Moscow          3
# ...          ...      ...    ...     ...  ...     ...         ...        ...
# 8931947   162399     3402  covid       0   48  Russia  Kurovskoye          0
# 8931948   162399     6747  movie       0   48  Russia  Kurovskoye          0
# 8931949   162399     2274   tech       0   48  Russia  Kurovskoye          0
# 8931950   162399     1909  sport       0   48  Russia  Kurovskoye          0
# 8931951   162399     1401  sport       0   48  Russia  Kurovskoye          0
#
#               os   source  hour  month
# 0            iOS      ads    12     11
# 1            iOS      ads    12     11
# 2            iOS      ads    12     11
# 3            iOS      ads    12     11
# 4            iOS      ads    12     11
# ...          ...      ...   ...    ...
# 8931947  Android  organic     7     12
# 8931948  Android  organic     7     12
# 8931949  Android  organic     7     12
# 8931950  Android  organic     7     12
# 8931951  Android  organic     7     12
#
# [8931952 rows x 12 columns]

# %%
# from sqlalchemy import create_engine

# engine = create_engine(
#     "postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
#     "postgres.lab.karpov.courses:6432/startml")

# df_new.to_sql('df_info_features_argymbek', con=engine, if_exists='replace', index=False)
# test_ = pd.read_sql('SELECT * FROM df_info_features_argymbek', con=engine)

# %%
# df_new.to_sql(    
#    "df_info_features_argymbek",                    
#     con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
#         "postgres.lab.karpov.courses:6432/startml",                      
#     schema="public",                   
#     if_exists='replace'            
#    )

# %%
# test_1 = pd.read_sql(
#     """SELECT * FROM public.df_info_features_argymbek""",
    
#     con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
#         "postgres.lab.karpov.courses:6432/startml"
# )

# test_1
